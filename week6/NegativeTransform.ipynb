# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
rice = cv2.imread("../open-cv/images/me2.jpg", cv2.IMREAD_GRAYSCALE)
print(rice.shape)
print(rice)
# Out:
# (960, 960)
# [[180 183 188 ... 226 225 219]
#  [187 186 187 ... 213 215 215]
#  [195 193 190 ... 212 211 212]
#  ...
#  [179 184 178 ... 190 193 191]
#  [174 167 168 ... 177 180 180]
#  [134 123 139 ... 177 179 177]]

# %%
negative_img = 256 - 1 - rice
print(negative_img)
# Out:
# [[ 75  72  67 ...  29  30  36]
#  [ 68  69  68 ...  42  40  40]
#  [ 60  62  65 ...  43  44  43]
#  ...
#  [ 76  71  77 ...  65  62  64]
#  [ 81  88  87 ...  78  75  75]
#  [121 132 116 ...  78  76  78]]

# %%
plt.imshow(negative_img, cmap='gray', interpolation='bicubic')
plt.show()
